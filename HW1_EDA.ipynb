# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import missingno

# %%
df = pd.read_csv('MARKETING_Customer_Lifetime_Value.csv')

# %%
df.shape
# Out:
# (9134, 25)

# %%
df.tail()
# Out:
#       Unnamed: 0 Customer       State  Customer_Lifetime_Value Response  \
# 9129        9129  LA72316  California             23405.987980       No
# 9130        9130  PK87824  California              3096.511217      Yes
# 9131        9131  TD14365  California              8163.890428       No
# 9132        9132  UP19263  California              7524.442436       No
# 9133        9133  Y167826  California              2611.836866       No
#
#       Coverage Education Effective_To_Date EmploymentStatus Gender  ...  \
# 9129     Basic  Bachelor        2011-02-10         Employed      M  ...
# 9130  Extended   College        2011-02-12         Employed      F  ...
# 9131  Extended  Bachelor        2011-02-06       Unemployed      M  ...
# 9132  Extended   College        2011-02-03         Employed      M  ...
# 9133  Extended   College        2011-02-14       Unemployed      M  ...
#
#       Months_Since_Policy_Inception Number_of_Open_Complaints  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer_Lifetime_Value',
#        'Response', 'Coverage', 'Education', 'Effective_To_Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location_Code',
#        'Marital_Status', 'Monthly_Premium_Auto', 'Months_Since_Last_Claim',
#        'Months_Since_Policy_Inception', 'Number_of_Open_Complaints',
#        'Number_of_Policies', 'Policy_Type', 'Policy', 'Renew_Offer_Type',
#        'Sales_Channel', 'Total_Claim_Amount', 'Vehicle_Class', 'Vehicle_Size'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer_Lifetime_Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective_To_Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location_Code                     object
# Marital_Status                    object
# Monthly_Premium_Auto               int64
# Months_Since_Last_Claim            int64
# Months_Since_Policy_Inception      int64
# Number_of_Open_Complaints          int64
# Number_of_Policies                 int64
# Policy_Type                       object
# Policy                            object
# Renew_Offer_Type                  object
# Sales_Channel                     object
# Total_Claim_Amount               float64
# ...

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0                       0
# Customer                         0
# State                            0
# Customer_Lifetime_Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective_To_Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location_Code                    0
# Marital_Status                   0
# Monthly_Premium_Auto             0
# Months_Since_Last_Claim          0
# Months_Since_Policy_Inception    0
# Number_of_Open_Complaints        0
# Number_of_Policies               0
# Policy_Type                      0
# Policy                           0
# Renew_Offer_Type                 0
# Sales_Channel                    0
# Total_Claim_Amount               0
# Vehicle_Class                    0
# Vehicle_Size                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
missingno.bar(df,color="dodgerblue") #just changing dark color to something more bright 
plt.show()

# %% [markdown]
# As we can see there aren't any missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     9134 non-null   int64
#  1   Customer                       9134 non-null   object
#  2   State                          9134 non-null   object
#  3   Customer_Lifetime_Value        9134 non-null   float64
#  4   Response                       9134 non-null   object
#  5   Coverage                       9134 non-null   object
#  6   Education                      9134 non-null   object
#  7   Effective_To_Date              9134 non-null   object
#  8   EmploymentStatus               9134 non-null   object
#  9   Gender                         9134 non-null   object
#  10  Income                         9134 non-null   int64
#  11  Location_Code                  9134 non-null   object
# ...

# %%
plt.hist(df['Customer_Lifetime_Value'], bins=20)
plt.xlabel('Customer_Lifetime_Value')
plt.ylabel('Count')
plt.title('Distribution of Customer_Lifetime_Value')
plt.show()

# %% [markdown]
# As you can see we have right tail histogram. The most part ov values are below 10000.

# %%
df=df.drop('Unnamed: 0',1)

# %%
df.describe()
# Out:
#        Customer_Lifetime_Value        Income  Monthly_Premium_Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months_Since_Last_Claim  Months_Since_Policy_Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# As you can see there are positive trend between customer liftime value, Monthly Premium auto and Total claim ammount

# %%
sns.color_palette("icefire", as_cmap=True)

# %%
sns.catplot(x="Education", y="Customer_Lifetime_Value", data=df, kind="box", aspect=1.5,palette='Blues')
sns.color_palette("icefire", as_cmap=True)
plt.yscale('log')
plt.title("Boxplot for Customer_Lifetime_Value vs Education")
plt.show()
#chnage the color to blue, whic will be more suitable for education

# %%
sns.barplot(x="EmploymentStatus", y="Customer_Lifetime_Value", data=df,palette='deep')
plt.title("Boxplot for Customer_Lifetime_Value vs Education")
plt.show()

# %%
data_num=df.select_dtypes(exclude="object")

# %%
corrmat = data_num.corr()
sns.heatmap(corrmat, annot=True,cmap="BuPu")
plt.show()

# %%
num_cols=data_num.columns.tolist()

# %%
num_cols
# Out:
# ['Customer_Lifetime_Value',
#  'Income',
#  'Monthly_Premium_Auto',
#  'Months_Since_Last_Claim',
#  'Months_Since_Policy_Inception',
#  'Number_of_Open_Complaints',
#  'Number_of_Policies',
#  'Total_Claim_Amount']

# %%
for num_col in num_cols:
  sns.displot(df[num_col], kde=True)
  plt.show()

# %%
sns.barplot(x="Response", y="Customer_Lifetime_Value", data=df,palette='colorblind')
plt.title("Boxplot for 'Response'")
plt.show()

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer_Lifetime_Value', 'Response', 'Coverage',
#        'Education', 'Effective_To_Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location_Code', 'Marital_Status', 'Monthly_Premium_Auto',
#        'Months_Since_Last_Claim', 'Months_Since_Policy_Inception',
#        'Number_of_Open_Complaints', 'Number_of_Policies', 'Policy_Type',
#        'Policy', 'Renew_Offer_Type', 'Sales_Channel', 'Total_Claim_Amount',
#        'Vehicle_Class', 'Vehicle_Size'],
#       dtype='object')

# %%
sns.barplot(x="Vehicle_Class", y="Customer_Lifetime_Value", hue='Gender',data=df,palette='Paired')
plt.title("Boxplot for 'Response'")
plt.show()

# %%
group_state = df.groupby('State').sum().sort_values('Customer_Lifetime_Value', ascending=False)

# %%
group_state
# Out:
#             Unnamed: 0  Customer_Lifetime_Value     Income  \
# State
# California    16396791             2.521149e+07  118310682
# Oregon        11073285             2.101062e+07   97686494
# Arizona        7165574             1.338786e+07   63701400
# Nevada         3741661             7.106015e+06   33841992
# Washington     3333100             6.401135e+06   30421941
#
#             Monthly_Premium_Auto  Months_Since_Last_Claim  \
# State
# California                294510                    47510
# Oregon                    243880                    38732
# Arizona                   156480                    25711
# Nevada                     83154                    13524
# Washington                 73441                    12419
#
#             Months_Since_Policy_Inception  Number_of_Open_Complaints  \
# State
# California                         150094                       1205
# Oregon                             125467                        946
# ...

# %%
sns.barplot(x=group_state.index, y="Customer_Lifetime_Value",data=group_state,palette='tab20c')
plt.title("Boxplot for Customer liftime value in states")
plt.show()
